# %% [markdown]
# <a href="https://colab.research.google.com/github/vivmaria18-del/Week-one-catchup/blob/main/25_UG_135_BSCE_J.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
STUDENT_ID = "25/UG/135/BSCE-J"  #
COHORT = "CML3112"

# %%
print("Hello from CML3112 - Civil Engineering ML Practical")
proof_sum = 2 + 2
print(proof_sum)
# Out:
# Hello from CML3112 - Civil Engineering ML Practical
# 4

# %%
readings = 12
readings = readings + 5
print(readings)
# Out:
# 17

# %% [markdown]
# ### Execution Order Explanation:
# When the previous cell (`readings = readings + 5`) is run multiple times, the value of `readings` increases by 5 with every run because Jupyter notebooks maintain state in memory across cell executions.
#
# When **Restart and Run All** is executed, the runtime state is reset to clean memory. The cells run sequentially from top to bottom, setting `readings = 12` first, and then executing `readings = readings + 5` exactly once, producing the expected fresh-run value of `17`.

# %%
import csv

with open("site_inspection_log.csv", newline="") as f:
    rows = list(csv.DictReader(f))

print(f"Successfully loaded {len(rows)} structural inspection records.")
# Out:
# Successfully loaded 4 structural inspection records.

# %%
from google.colab import drive
drive.mount('/content/drive')
